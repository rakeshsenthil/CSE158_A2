# %%
import gzip
from collections import defaultdict
import random
import pandas as pd
import numpy as np
import string
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer as tfv
import json

# %%
def parse(path):
    g = gzip.open(path, 'r')
    for l in g:
        yield json.loads(l)

# %%
runway_json = (parse('renttherunway_final_data.json.gz'))

# %%
df =  pd.DataFrame.from_records(runway_json)
df
# Out:
#         fit user_id bust size  item_id  weight rating     rented for  \
# 0       fit  420272       34d  2260466  137lbs     10       vacation
# 1       fit  273551       34b   153475  132lbs     10          other
# 2       fit  360448       NaN  1063761     NaN     10          party
# 3       fit  909926       34c   126335  135lbs      8  formal affair
# 4       fit  151944       34b   616682  145lbs     10        wedding
# ...     ...     ...       ...      ...     ...    ...            ...
# 192539  fit   66386      34dd  2252812  140lbs     10           work
# 192540  fit  118398       32c   682043  100lbs     10           work
# 192541  fit   47002       36a   683251  135lbs      6       everyday
# 192542  fit  961120       36c   126335  165lbs     10        wedding
# 192543  fit  123612       36b   127865  155lbs     10        wedding
#
#                                               review_text          body type  \
# ...

# %%
# Explore
df.fit.unique()
# Out:
# array(['fit', 'small', 'large'], dtype=object)

# %%
df['rented for'].unique()
# Out:
# array(['vacation', 'other', 'party', 'formal affair', 'wedding', 'date',
#        'everyday', 'work', nan, 'party: cocktail'], dtype=object)

# %%
def standardize_weight(string):
    string = string.lower()
    string = string.strip()
    string = string.replace('lbs','')
    string = string.strip()
    if string.isnumeric():
        return int(string)
    else:
        return np.nan

# %%
df['weight'] = df['weight'].astype(str).apply(standardize_weight)

# %%
df
# Out:
#         fit user_id bust size  item_id  weight rating     rented for  \
# 0       fit  420272       34d  2260466   137.0     10       vacation
# 1       fit  273551       34b   153475   132.0     10          other
# 2       fit  360448       NaN  1063761     NaN     10          party
# 3       fit  909926       34c   126335   135.0      8  formal affair
# 4       fit  151944       34b   616682   145.0     10        wedding
# ...     ...     ...       ...      ...     ...    ...            ...
# 192539  fit   66386      34dd  2252812   140.0     10           work
# 192540  fit  118398       32c   682043   100.0     10           work
# 192541  fit   47002       36a   683251   135.0      6       everyday
# 192542  fit  961120       36c   126335   165.0     10        wedding
# 192543  fit  123612       36b   127865   155.0     10        wedding
#
#                                               review_text          body type  \
# ...
